# %%
import pandas as pd
from sklearn import utils,preprocessing

df=pd.read_csv('Clean_Dataset.csv')
df=df.drop(columns='Unnamed: 0')
df=utils.shuffle(df,random_state=1) # shuffling before splitting into training & evaluation (swl oumaima wsh blan tdar hadi wla la)

#### i wanna see the unique values of each column

for col in df.columns:
    print(col)
    display(df[col].unique())
# Out:
# airline
# <StringArray>
# ['Air_India', 'Indigo', 'AirAsia', 'Vistara', 'SpiceJet', 'GO_FIRST']
# Length: 6, dtype: str
# flight
# <StringArray>
# [ 'AI-770',  '6E-161',  'I5-330', '6E-5214',  'UK-814',  'UK-851', 'SG-8169',
#   'UK-852',  'UK-877', 'SG-4031',
#  ...
#  'SG-6018', 'SG-9974',  'G8-405',  'I5-737',  'G8-107', 'SG-9923', 'SG-1058',
#  '6E-6613', '6E-6719', '6E-6474']
# Length: 1561, dtype: str
# source_city
# <StringArray>
# ['Kolkata', 'Bangalore', 'Mumbai', 'Delhi', 'Hyderabad', 'Chennai']
# Length: 6, dtype: str
# departure_time
# <StringArray>
# ['Night', 'Afternoon', 'Morning', 'Early_Morning', 'Evening', 'Late_Night']
# Length: 6, dtype: str
# stops
# <StringArray>
# ['one', 'zero', 'two_or_more']
# Length: 3, dtype: str
# arrival_time
# <StringArray>
# ['Morning', 'Evening', 'Early_Morning', 'Afternoon', 'Late_Night', 'Night']
# Length: 6, dtype: str
# destination_city
# <StringArray>
# ['Mumbai', 'Kolkata', 'Chennai', 'Hyderabad', 'Delhi', 'Bangalore']
# Length: 6, dtype: str
# class
# <StringArray>
# ['Economy', 'Business']
# Length: 2, dtype: str
# duration
# array([13.67,  6.08,  8.25,  5.08, 12.5 ,  7.17, 12.25, 14.67, 25.75,
#        24.67, 16.42,  5.58,  9.5 , 11.33, 10.17,  4.  ,  7.67, 25.33,
#         7.58, 25.17,  5.25, 22.33, 11.83, 12.58, 11.67,  7.  , 10.42,
#        13.33,  2.92,  4.25,  8.08, 10.58, 13.17, 11.42,  2.75, 25.25,
#        22.25,  6.67,  8.58,  2.25, 15.17, 15.83, 26.42,  5.67,  1.58,
#         9.67, 12.92, 14.08, 10.25, 26.  ,  4.33,  9.83, 27.33, 24.33,
#        23.17,  8.83,  4.42, 25.92,  9.17, 17.17, 10.75, 19.  , 10.5 ,
#        12.17, 15.92, 34.58, 16.17, 14.92, 23.67,  9.58, 15.08, 12.  ,
#         2.17, 27.08,  1.92,  7.33, 21.92, 40.67,  5.83, 49.83,  2.67,
#        13.83,  4.67, 11.58, 21.25, 24.92,  3.25,  4.75, 11.25,  7.25,
#        14.  , 11.5 , 27.17,  2.58,  5.5 , 13.08,  2.33,  7.5 ,  5.  ,
#         6.  , 12.67, 23.83, 14.25, 23.  , 11.75,  8.  , 13.92, 28.  ,
#         1.83, 23.33, 15.67, 14.42,  7.92, 24.17, 16.  ,  5.42,  5.75,
#        26.5 , 12.42,  1.75,  6.25, 13.42,  9.25, 20.42, 29.17, 19.83,
#         4.5 , 15.58, 26.33,  2.08,  6.33, 27.5 , 17.58,  2.5 , 22.08,
#         9.42, 14.75, 16.75,  7.08,  9.75,  6.75, 16.08, 20.67, 15.75,
#         1.42, 22.5 , 11.17,  8.42,  8.17, 14.17, 16.33, 17.75, 33.67,
#        15.  , 16.5 , 19.17, 28.67,  9.08, 26.58,  6.17, 26.83,  6.58,
#        21.58, 24.08, 14.83, 15.25, 24.83, 10.67, 10.08,  8.33, 21.5 ,
#        17.83, 12.83,  8.67, 13.  , 18.67,  6.42, 21.75, 16.25, 21.  ,
#        10.  , 12.33, 14.33,  8.92,  1.67, 15.42, 20.92, 12.08,  1.5 ,
#        25.42,  1.17, 35.08, 17.08, 17.42, 10.33, 25.  ,  5.92,  4.92,
#        14.58, 18.25, 23.5 , 25.08,  2.83, 13.25, 19.42, 22.67, 13.75,
#        14.5 ,  1.33, 18.92, 18.33, 21.33, 28.75, 25.58,  1.08,  7.75,
#        13.58, 21.42,  5.33, 20.  ,  5.17,  4.08, 20.83,  6.92, 25.67,
#         9.33, 12.75, 25.83, 17.92, 15.5 , 22.17, 30.  , 16.67, 23.75,
#         9.92, 20.33,  8.75, 17.5 , 19.5 , 11.92, 10.92,  8.5 , 18.  ,
#         7.42, 13.5 , 18.83, 21.67,  3.92,  9.  , 26.25,  1.25, 26.17,
#         6.5 ,  0.92, 20.08, 28.5 , 17.  , 17.33, 19.08, 20.17, 11.  ,
#        18.58, 18.42, 11.08, 20.58,  2.42, 17.25,  6.83, 28.42, 16.83,
#        37.  , 22.42, 19.92, 26.92, 24.5 ,  4.83, 26.08, 24.  , 22.92,
#         3.67, 27.75,  3.  , 26.67, 27.58, 23.58, 10.83, 29.42, 25.5 ,
#         7.83, 29.5 , 22.75, 23.42, 26.75, 23.92, 22.  , 15.33, 30.58,
#        19.33, 31.58, 33.5 , 16.92, 31.08, 37.33, 23.25, 22.83, 24.58,
#         3.33, 19.75, 20.5 , 21.83, 28.08,  1.  ,  3.83, 31.17, 23.08,
#        36.42, 24.75, 28.25,  4.58, 21.08,  0.83,  2.  , 32.08,  3.75,
#        16.58, 20.25, 18.08, 17.67, 18.17,  4.17, 35.75, 29.83, 19.67,
#        24.42, 28.58, 21.17, 18.5 ,  3.08, 18.75, 33.58, 31.92, 27.92,
#        20.75, 19.25, 35.42, 37.67, 28.33, 27.25, 37.08, 30.25, 30.33,
#         3.58, 22.58,  3.17, 32.17, 32.83, 27.  , 33.  , 34.33, 31.33,
#        33.33, 28.83, 28.17, 19.58,  3.5 , 33.42, 24.25, 27.42, 30.08,
#        29.67,  3.42, 28.92, 33.83, 31.25, 27.67, 40.42, 32.75, 34.17,
#        29.25, 34.75, 36.08, 38.58, 29.  , 27.83, 35.25, 32.58, 45.83,
#        32.  , 30.83, 30.42, 32.92, 32.42, 31.5 , 30.75, 30.5 , 33.92,
#        32.67, 31.83, 29.58, 36.92, 29.92, 34.25, 31.  , 34.83, 36.83,
#        33.75, 36.  , 29.75, 30.67, 13.4 , 31.75, 35.58, 34.  , 31.67,
#         6.07, 34.42, 29.33, 30.17, 37.58, 35.92, 41.08, 34.5 , 29.08,
#        36.75, 32.5 ,  6.98, 34.08, 37.92, 39.67, 35.17, 34.67, 40.92,
#        38.33, 34.92, 35.33, 33.17, 36.58, 33.08, 40.5 , 37.25, 30.92,
#        36.5 , 33.25, 41.5 , 39.42, 47.75, 35.5 , 41.83, 37.17, 36.17,
#        37.83, 39.  , 35.83, 42.  , 31.42, 39.25, 32.33, 39.92, 39.83,
#        38.83, 37.75, 35.67, 41.58, 32.25, 40.75, 47.08, 37.5 , 39.75,
#        39.08, 38.67, 37.42, 40.  , 36.25, 38.75, 38.5 , 44.5 ])
# days_left
# array([49, 11, 23, 43, 31, 15, 41, 30, 27, 28, 18, 38, 36, 14, 16, 48, 35,
#         2, 39, 47,  8, 32,  3, 20, 22, 12,  6, 46, 10,  9, 40, 19, 26, 37,
#        21,  7, 25, 44,  1, 13, 45, 34,  4, 33, 17, 24, 42,  5, 29])
# price
# array([ 6048, 13421,  2836, ..., 38406, 80827, 40862], shape=(12157,))

# %% [markdown]
# the columns (features) that should be encoded are:
# airline, flights, departure & arrival times, source & destination cities, stops, class
#
# the other ones are already numerical & don't need any more encoding (days_left, price, duration)
#
# i suppose all the data in here is relevant to use in the ML Training
#
# [doc for preprocessing](https://scikit-learn.org/stable/modules/preprocessing.html#encoding-categorical-features)

# %%
#### Preprocessing (Encoding)
enc=preprocessing.OneHotEncoder()
enc.fit(df[['airline']])
# Out:
# OneHotEncoder()
