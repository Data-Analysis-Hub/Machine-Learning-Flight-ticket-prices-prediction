# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("Clean_Dataset.csv")
df=df.drop(columns='Unnamed: 0')
df
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# 0                Mumbai   Economy      2.17          1   5953
# 1                Mumbai   Economy      2.33          1   5953
# 2                Mumbai   Economy      2.17          1   5956
# 3                Mumbai   Economy      2.25          1   5955
# 4                Mumbai   Economy      2.33          1   5955
# ...                 ...       ...       ...        ...    ...
# 300148        Hyderabad  Business     10.08         49  69265
# 300149        Hyderabad  Business     10.42         49  77105
# 300150        Hyderabad  Business     13.83         49  79099
# 300151        Hyderabad  Business     10.00         49  81585
# 300152        Hyderabad  Business     10.08         49  81585
#
# [300153 rows x 11 columns]

# %%
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %% [markdown]
# # variables countinues
#         * duration
#         * price
# # variables discrete
#     -- discrete categorical
#         * airline
#         * flight
#         * sourc_city
#         * destination_city
#         * calss
#         * stops
#     -- discrete ordinal
#         * arrival_time
#         * days_left
#         * departure_time

# %%
#looking for messing values
df.isnull().sum()
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
# chake for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (300153, 11)

# %%
#infos about data types and columes
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  str
#  1   flight            300153 non-null  str
#  2   source_city       300153 non-null  str
#  3   departure_time    300153 non-null  str
#  4   stops             300153 non-null  str
#  5   arrival_time      300153 non-null  str
#  6   destination_city  300153 non-null  str
#  7   class             300153 non-null  str
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), str(8)
# memory usage: 25.2 MB

# %% [markdown]
# # 3️⃣ Univariate analysis

# %%
#analys 
df["price"].describe()
# Out:
# count    300153.000000
# mean      20889.660523
# std       22697.767366
# min        1105.000000
# 25%        4783.000000
# 50%        7425.000000
# 75%       42521.000000
# max      123071.000000
# Name: price, dtype: float64

# %%
# histogramme de price
plt.figure(figsize=(12, 5))
plt.hist(df['price'], bins=50)
plt.title('Histogramme de price')
plt.show()

# boxplot de price
plt.figure(figsize=(12, 5))
plt.boxplot(df['price'])
plt.title('Boxplot de price')
plt.show()

# %%
print(df['airline'].value_counts())

# bar plot de airline
plt.figure(figsize=(12, 5))
df['airline'].value_counts().plot(kind='bar')
plt.title('Distribution de airline')
plt.show()
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64

# %%
# distribution de source_city
print(df['source_city'].value_counts())

# bar plot de source_city
plt.figure(figsize=(12, 5))
df['source_city'].value_counts().plot(kind='bar')
plt.title('Distribution de source_city')
plt.show()
# Out:
# source_city
# Delhi        61343
# Mumbai       60896
# Bangalore    52061
# Kolkata      46347
# Hyderabad    40806
# Chennai      38700
# Name: count, dtype: int64

# %%
# distribution de destination_city
print(df['destination_city'].value_counts())

# bar plot de destination_city
plt.figure(figsize=(12, 5))
df['destination_city'].value_counts().plot(kind='bar')
plt.title('Distribution de destination_city')
plt.show()
# Out:
# destination_city
# Mumbai       59097
# Delhi        57360
# Bangalore    51068
# Kolkata      49534
# Hyderabad    42726
# Chennai      40368
# Name: count, dtype: int64

# %%
# distribution de departure_time
print(df['departure_time'].value_counts())

# bar plot de departure_time
plt.figure(figsize=(12, 5))
df['departure_time'].value_counts().plot(kind='bar')
plt.title('Distribution de departure_time')
plt.show()
# Out:
# departure_time
# Morning          71146
# Early_Morning    66790
# Evening          65102
# Night            48015
# Afternoon        47794
# Late_Night        1306
# Name: count, dtype: int64

# %%
# distribution de arrival_time
print(df['arrival_time'].value_counts())

# bar plot de arrival_time
plt.figure(figsize=(12, 5))
df['arrival_time'].value_counts().plot(kind='bar')
plt.title('Distribution de arrival_time')
plt.show()
# Out:
# arrival_time
# Night            91538
# Evening          78323
# Morning          62735
# Afternoon        38139
# Early_Morning    15417
# Late_Night       14001
# Name: count, dtype: int64

# %%
# distribution de stops
print(df['stops'].value_counts())

# bar plot de stops
plt.figure(figsize=(12, 5))
df['stops'].value_counts().plot(kind='bar')
plt.title('Distribution de stops')
plt.show()
# Out:
# stops
# one            250863
# zero            36004
# two_or_more     13286
# Name: count, dtype: int64

# %%
# distribution de class
print(df['class'].value_counts())

# bar plot de class
plt.figure(figsize=(12, 5))
df['class'].value_counts().plot(kind='bar')
plt.title('Distribution de class')
plt.show()
# Out:
# class
# Economy     206666
# Business     93487
# Name: count, dtype: int64

# %%
# VARIABLES NUMÉRIQUES

# stats descriptives de duration
print(df['duration'].describe())

# histogramme de duration
plt.figure(figsize=(12, 5))
plt.hist(df['duration'], bins=50)
plt.title('Histogramme de duration')
plt.show()
# boxplot de duration
plt.figure(figsize=(12, 5))
plt.boxplot(df['duration'],vert=False)
plt.title('Boxplot de duration')
plt.show()
# Out:
# count    300153.000000
# mean         12.221021
# std           7.191997
# min           0.830000
# 25%           6.830000
# 50%          11.250000
# 75%          16.170000
# max          49.830000
# Name: duration, dtype: float64

# %%
# stats descriptives de days_left
print(df['days_left'].describe())
bins=len(df['days_left'].value_counts().sort_index())

# histogramme de days_left
plt.figure(figsize=(12, 5))
plt.hist(df['days_left'], bins=bins)
plt.title('Histogramme de days_left')
plt.show()
# boxplot de days_left
plt.figure(figsize=(12, 5))
plt.boxplot(df['days_left'])
plt.title('Boxplot de days_left')
plt.show()
# Out:
# count    300153.000000
# mean         26.004751
# std          13.561004
# min           1.000000
# 25%          15.000000
# 50%          26.000000
# 75%          38.000000
# max          49.000000
# Name: days_left, dtype: float64

# %%
df['airline'].value_counts()
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64

# %% [markdown]
# # 4️⃣ Multivariate analysis

# %%
plt.figure(figsize=(12, 5))
sns.regplot(data = df, x = df['duration'], y = df['price'])
plt.title("flight duration vs price")
# Out:
# Text(0.5, 1.0, 'flight duration vs price')

# %%
order_by_price =df.groupby('airline') ['price'].mean().sort_values(ascending=False).index

plt.figure(figsize=(12, 5))
sns.barplot(data = df , x="airline", y ="price", errorbar=None, order=order_by_price,palette="winter")
plt.title("airline vs price", c = 'k', fontsize = 20)
# Out:
# C:\Users\Hamza\AppData\Local\Temp\ipykernel_10172\4054030297.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = df , x="airline", y ="price", errorbar=None, order=order_by_price,palette="winter")
# Text(0.5, 1.0, 'airline vs price')

# %%
order_list = df.groupby('stops')['price'].mean().sort_values(ascending=False).index

plt.figure(figsize=(12, 5))
sns.barplot(data = df, x = df['stops'], y = df['price'], errorbar= None, hue = df['stops'], order = order_list,palette="winter")
plt.title("number of stops overs vs. price", c = 'k', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'number of stops overs vs. price')

# %%
plt.figure(figsize=(12, 5))
sns.lineplot(data = df , x = df['days_left'], y = df['price'], c = 'orange')
plt.title("days before flight vs price", c = 'k', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'days before flight vs price')

# %%
pivot = df.pivot_table(
    index="stops",
    columns="airline",
    values="price",
    aggfunc="mean"
)

plt.figure(figsize=(12, 6))

sns.heatmap(
    pivot,
    cmap="viridis",
    annot=True,
    fmt=".0f",
)

plt.title("Average Price by Airline and Number of Stops")
plt.xlabel("Airline")
plt.ylabel("Stops")

plt.xticks(rotation=45)
plt.show()

# %%
pivot2 = df.pivot_table(
    index="departure_time",
    columns="class",
    values="price",
    aggfunc="mean"
)

plt.figure(figsize=(7,4))

sns.heatmap(
    pivot2,
    cmap="coolwarm",
    annot=True,
    fmt=".0f"
)

plt.title("Price by Departure Time and Class")
plt.show()

# %% [markdown]
# Cette heatmap montre que la classe est le facteur principal influençant le prix des billets, avec des tarifs beaucoup plus élevés en Business qu’en Economy, tandis que l’heure de départ a un impact secondaire légèrement visible sur les prix.
