# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("Clean_Dataset.csv")
df

# %%
df.head()

# %% [markdown]
# # variables countinues
#         * duration
#         * price
# # variables discrete
#     -- discrete categorical
#         * airline
#         * flight
#         * sourc_city
#         * destination_city
#         * calss
#         * days_left
#         * stops
#     -- discrete ordinal
#         * arrival_time
#         * departure_time
#         * Unnamed: 0

# %%
#looking for messing values
df.isnull().sum()

# %%
# chake for duplicates
df.duplicated().sum()

# %%
df.shape

# %%
#infos about data types and columes
df.info()

# %%
#analys 
df["price"].describe()

# %%
sns.boxplot(data= df , x= "price")

# %%
sns.displot(data= df , x= "price")

# %%
# DISTRIBUTION DES PRIX
df.groupby('class')['price'].mean()
sns.boxplot(data = df , x="class", y ="price")

# %%
df['airline'].value_counts()

# %%
# ANALYSE DES COMPAGNIES
                    
df.groupby('airline')['price'].mean() 
sns.boxplot(data = df , x="price", y ="airline")

# %%
sns.barplot(data = df , x="airline", y ="price", errorbar=None, hue = 'airline')

# %%
#ANALYSE DES ROUTES

df['source_city'].value_counts()

# %%
df.groupby(['source_city','destination_city'])['price'].mean()

# %%
msdqjfklqsdmkl
