# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("Clean_Dataset.csv")
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %% [markdown]
# # countinues varianles
#         * duration
#         * price
# # descrit variables
#     -- descrit catigorial
#         * airline
#         * flight
#         * sourc_city
#         * destination_city
#         * calss
#         * days_left
#         * stops
#     -- descrit calssification
#         * arrival_time
#         * departure_time
#         * Unnamed: 0

# %%
#looking for messing values
df.isnull().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
#
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (300153, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  str
#  2   flight            300153 non-null  str
#  3   source_city       300153 non-null  str
#  4   departure_time    300153 non-null  str
#  5   stops             300153 non-null  str
#  6   arrival_time      300153 non-null  str
#  7   destination_city  300153 non-null  str
#  8   class             300153 non-null  str
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), str(8)
# memory usage: 27.5 MB

# %%
df["price"].describe()
# Out:
# count    300153.000000
# mean      20889.660523
# std       22697.767366
# min        1105.000000
# 25%        4783.000000
# 50%        7425.000000
# 75%       42521.000000
# max      123071.000000
# Name: price, dtype: float64

# %%
# histogramme de price
plt.hist(df['price'], bins=50)
plt.title('Histogramme de price')
plt.show()

# boxplot de price
plt.boxplot(df['price'])
plt.title('Boxplot de price')
plt.show()

# %%
print(df['airline'].value_counts())

# bar plot de airline
df['airline'].value_counts().plot(kind='bar')
plt.title('Distribution de airline')
plt.show()
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64

# %%
# distribution de source_city
print(df['source_city'].value_counts())

# bar plot de source_city
df['source_city'].value_counts().plot(kind='bar')
plt.title('Distribution de source_city')
plt.show()
# Out:
# source_city
# Delhi        61343
# Mumbai       60896
# Bangalore    52061
# Kolkata      46347
# Hyderabad    40806
# Chennai      38700
# Name: count, dtype: int64

# %%
# distribution de destination_city
print(df['destination_city'].value_counts())

# bar plot de destination_city
df['destination_city'].value_counts().plot(kind='bar')
plt.title('Distribution de destination_city')
plt.show()
# Out:
# destination_city
# Mumbai       59097
# Delhi        57360
# Bangalore    51068
# Kolkata      49534
# Hyderabad    42726
# Chennai      40368
# Name: count, dtype: int64

# %%
# distribution de departure_time
print(df['departure_time'].value_counts())

# bar plot de departure_time
df['departure_time'].value_counts().plot(kind='bar')
plt.title('Distribution de departure_time')
plt.show()
# Out:
# departure_time
# Morning          71146
# Early_Morning    66790
# Evening          65102
# Night            48015
# Afternoon        47794
# Late_Night        1306
# Name: count, dtype: int64

# %%
# distribution de arrival_time
print(df['arrival_time'].value_counts())

# bar plot de arrival_time
df['arrival_time'].value_counts().plot(kind='bar')
plt.title('Distribution de arrival_time')
plt.show()
# Out:
# arrival_time
# Night            91538
# Evening          78323
# Morning          62735
# Afternoon        38139
# Early_Morning    15417
# Late_Night       14001
# Name: count, dtype: int64

# %%
# distribution de stops
print(df['stops'].value_counts())

# bar plot de stops
df['stops'].value_counts().plot(kind='bar')
plt.title('Distribution de stops')
plt.show()
# Out:
# stops
# one            250863
# zero            36004
# two_or_more     13286
# Name: count, dtype: int64

# %%
# distribution de class
print(df['class'].value_counts())

# bar plot de class
df['class'].value_counts().plot(kind='bar')
plt.title('Distribution de class')
plt.show()
# Out:
# class
# Economy     206666
# Business     93487
# Name: count, dtype: int64

# %%
# VARIABLES NUMÉRIQUES

# stats descriptives de duration
print(df['duration'].describe())

# histogramme de duration
plt.hist(df['duration'], bins=50)
plt.title('Histogramme de duration')
plt.show()
# boxplot de duration
plt.boxplot(df['duration'])
plt.title('Boxplot de duration')
plt.show()
# Out:
# count    300153.000000
# mean         12.221021
# std           7.191997
# min           0.830000
# 25%           6.830000
# 50%          11.250000
# 75%          16.170000
# max          49.830000
# Name: duration, dtype: float64

# %%
# stats descriptives de days_left
print(df['days_left'].describe())

# histogramme de days_left
plt.hist(df['days_left'], bins=50)
plt.title('Histogramme de days_left')
plt.show()
# boxplot de days_left
plt.boxplot(df['days_left'])
plt.title('Boxplot de days_left')
plt.show()
# Out:
# count    300153.000000
# mean         26.004751
# std          13.561004
# min           1.000000
# 25%          15.000000
# 50%          26.000000
# 75%          38.000000
# max          49.000000
# Name: days_left, dtype: float64

# %%
# DISTRIBUTION DES PRIX
df.groupby('class')['price'].mean()
sns.boxplot(data = df , x="class", y ="price")
# Out:
# <Axes: xlabel='class', ylabel='price'>

# %%
# ANALYSE DES COMPAGNIES
                    
df.groupby('airline')['price'].mean() 
sns.boxplot(data = df , x="price", y ="airline")
# Out:
# <Axes: xlabel='price', ylabel='airline'>

# %%
sns.barplot(data = df , x="airline", y ="price", errorbar=None, hue = 'airline')
# Out:
# <Axes: xlabel='airline', ylabel='price'>

# %%
#ANALYSE DES ROUTES

df['source_city'].value_counts()
# Out:
# source_city
# Delhi        61343
# Mumbai       60896
# Bangalore    52061
# Kolkata      46347
# Hyderabad    40806
# Chennai      38700
# Name: count, dtype: int64

# %%
df.groupby(['source_city','destination_city'])['price'].mean()
# Out:
# source_city  destination_city
# Bangalore    Chennai             23321.850078
#              Delhi               17723.313972
#              Hyderabad           21226.121192
#              Kolkata             23500.061229
#              Mumbai              23128.618672
# Chennai      Bangalore           25081.850454
#              Delhi               18981.863948
#              Hyderabad           21591.345404
#              Kolkata             22669.932407
#              Mumbai              22765.849647
# Delhi        Bangalore           17880.216315
#              Chennai             19369.881354
#              Hyderabad           17347.288379
#              Kolkata             20566.409418
#              Mumbai              19355.829812
# Hyderabad    Bangalore           21347.177998
#              Chennai             21848.065989
#              Delhi               17243.945685
#              Kolkata             20823.893201
#              Mumbai              20080.865759
# ...
